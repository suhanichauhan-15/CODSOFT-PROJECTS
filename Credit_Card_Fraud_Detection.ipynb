# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanichauhan-15/FRONTEND/blob/master/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 5 : Credit Card Fraud Detection**
#
# Author:Suhani Chauhan
#  Batch: July-august 25
#
# Domain: Data Science

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
file=pd.read_csv("/content/creditcard.csv")

# %%
file.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
file.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean   10121.161817     -0.235676      0.284287      0.846047      0.302775
# std     7739.625811      1.720315      1.394804      1.561376      1.500595
# min        0.000000    -27.670569    -34.607649    -24.667741     -4.657545
# 25%     2984.250000     -0.969786     -0.282728      0.407297     -0.623141
# 50%     9086.500000     -0.319439      0.252904      0.960978      0.220104
# 75%    17103.500000      1.162662      0.884741      1.607031      1.198942
# max    24759.000000      1.960497     10.558600      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean      -0.118730      0.128013     -0.157297     -0.016148      0.989827
# ...

# %%
file.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
file['Class'].value_counts()
# Out:
# Class
# 0.0    13897
# 1.0       56
# Name: count, dtype: int64

# %%
normal=file[file.Class==0]

# %%
fraud=file[file.Class==1]

# %%
print(normal.shape)
# Out:
# (13897, 31)

# %%
print(normal.shape)
# Out:
# (13897, 31)

# %%
normal.Amount.describe()
# Out:
# count    13897.000000
# mean        63.773909
# std        177.164503
# min          0.000000
# 25%          5.770000
# 50%         15.900000
# 75%         52.370000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      56.000000
# mean       90.815893
# std       310.308450
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.025000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
file.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10111.481255 -0.217093  0.266252  0.887227  0.276789 -0.107510
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.136745 -0.131462 -0.020385  1.005460  ...  0.020758 -0.068686
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.158230 -0.034834  0.013065  0.117928  0.034349  0.009565  0.002329
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    63.773909
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %%
normal_sample=normal.sample(n=492)

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 2504    2079 -1.104299  1.345855  1.208586  1.650182  0.708719 -0.078664
# 9758   14485  1.162463 -0.084011  0.870322  0.158787 -0.575669 -0.042212
# 11186  19381  1.132690 -0.353440 -0.231304  0.818512  1.671776  4.442033
# 11093  19169 -0.314090  1.211158  1.590803  0.653890  0.243553 -0.803299
# 6083    6927  1.213107 -0.408434  0.292119 -0.073691 -0.514569 -0.055445
# 13506  23926 -0.257720  0.906397  1.554707  0.091535  1.038740  0.771148
# 6803    8575  0.975840  0.289995  0.758432  2.713666 -0.023551  0.449936
# 5562    5682 -0.439295  1.146700  1.410151  0.232860  0.372895 -0.480126
# 4823    4311 -1.012157  0.763410  2.029957 -0.142263  0.628415 -1.152739
# 11038  19044 -1.169579 -0.590007 -0.100819  0.567371  2.933560  3.415871
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 2504   0.688576 -0.017308 -0.791764  ... -0.347870 -0.761656  0.188575
# ...

# %%
new_file['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     56
# Name: count, dtype: int64

# %%
new_file.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10571.961382 -0.155386  0.273990  0.930651  0.255967 -0.102265
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.131009 -0.107901  0.036285  1.055361  ... -0.003216 -0.078829
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.104400 -0.019354  0.027588  0.113788  0.029007 -0.005344 -0.015132
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    50.598171
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,Y_train)*100

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 99.08675799086758%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)*100

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 100.0%
